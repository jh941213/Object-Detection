# %% [markdown]
# <a href="https://colab.research.google.com/github/jh941213/Object-Detection/blob/main/colab_loacal_install_how.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 로컬에 코랩 연결하기
# 출처 : https://research.google.com/colaboratory/local-runtimes.html

# %% [markdown]
# jupyter 를 사용해야 한다.

# %% [markdown]
# ### jupyter_http_over_ws jupyter 확장 프로그램 설치 및 사용 설정(처음 한 번만 실행)

# %% [markdown]
# 로컬 환경에서 위의 확장 프로그램을 설치하고 사용 설정한다.
# - pip install jupyter_http_over_ws
# - jupyter serverextension enable --py jupyter_http_over_ws

# %% [markdown]
# ### 플래그를 설정한다.

# %% [markdown]
# jupyter notebook
#   --NotebookApp.allow_origin='https://colab.research.google.com'
#   --port=8888
#   --NotebookApp.port_retries=0

# %% [markdown]
# 아래 링크를 복사해준다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 로컬 런타임에 연결
# 이제 Colab으로 돌아와서 (우측 상단) 연결 > 로컬 런타임에 연결
# - 복사해둔 링크를 입력해준다.
